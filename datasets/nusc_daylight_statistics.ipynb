# %%
import os
from nuscenes_config.splits import train, val
from pathlib import Path

# %%
root = Path("/home/stud/xiji/storage/slurm/nuscenes_416_256/training")
matching_folders = sorted([f for f in root.iterdir() if f.is_dir() and f.name.endswith("_0")])

for folder in matching_folders:
    print(folder.name)
# Out:
# scene-0001_0
# scene-0002_0
# scene-0003_0
# scene-0004_0
# scene-0005_0
# scene-0006_0
# scene-0007_0
# scene-0008_0
# scene-0009_0
# scene-0010_0
# scene-0011_0
# scene-0012_0
# scene-0013_0
# scene-0014_0
# scene-0015_0
# scene-0016_0
# scene-0017_0
# scene-0018_0
# scene-0019_0
# scene-0020_0
# scene-0021_0
# scene-0022_0
# scene-0023_0
# scene-0024_0
# scene-0025_0
# scene-0026_0
# scene-0027_0
# scene-0028_0
# scene-0029_0
# scene-0030_0
# scene-0031_0
# scene-0032_0
# scene-0033_0
# scene-0034_0
# scene-0035_0
# scene-0036_0
# scene-0038_0
# scene-0039_0
# scene-0041_0
# scene-0042_0
# scene-0043_0
# scene-0044_0
# scene-0045_0
# scene-0046_0
# scene-0047_0
# scene-0048_0
# scene-0049_0
# scene-0050_0
# scene-0051_0
# scene-0052_0
# scene-0053_0
# scene-0054_0
# scene-0055_0
# scene-0056_0
# scene-0057_0
# scene-0058_0
# scene-0059_0
# scene-0060_0
# scene-0061_0
# scene-0062_0
# scene-0063_0
# scene-0064_0
# scene-0065_0
# scene-0066_0
# scene-0067_0
# scene-0068_0
# ...

# %%
train_list = sorted([
    folder.name.split("_")[0]
    for folder in root.iterdir()
    if folder.is_dir() and folder.name.endswith("_0") and folder.name.split("_")[0] in train
])
print(len(train_list))
train_list
616 * 220
# Out:
# 616
# ['scene-0001',
#  'scene-0002',
#  'scene-0004',
#  'scene-0005',
#  'scene-0006',
#  'scene-0007',
#  'scene-0008',
#  'scene-0009',
#  'scene-0010',
#  'scene-0011',
#  'scene-0019',
#  'scene-0020',
#  'scene-0021',
#  'scene-0022',
#  'scene-0023',
#  'scene-0024',
#  'scene-0025',
#  'scene-0026',
#  'scene-0027',
#  'scene-0028',
#  'scene-0029',
#  'scene-0030',
#  'scene-0031',
#  'scene-0032',
#  'scene-0033',
#  'scene-0034',
#  'scene-0041',
#  'scene-0042',
#  'scene-0043',
#  'scene-0044',
#  'scene-0045',
#  'scene-0046',
#  'scene-0047',
#  'scene-0048',
#  'scene-0049',
#  'scene-0050',
#  'scene-0051',
#  'scene-0052',
#  'scene-0053',
#  'scene-0054',
#  'scene-0055',
#  'scene-0056',
#  'scene-0057',
#  'scene-0058',
#  'scene-0059',
#  'scene-0060',
#  'scene-0061',
#  'scene-0062',
#  'scene-0063',
#  'scene-0064',
#  'scene-0065',
#  'scene-0066',
#  'scene-0067',
#  'scene-0068',
#  'scene-0069',
#  'scene-0070',
#  'scene-0071',
#  'scene-0072',
# ...

# %%
val_list = sorted([
    folder.name.split("_")[0]
    for folder in root.iterdir()
    if folder.is_dir() and folder.name.endswith("_0") and folder.name.split("_")[0] in val
])
print(len(val_list))
val_list
# Out:
# 135
# ['scene-0003',
#  'scene-0012',
#  'scene-0013',
#  'scene-0014',
#  'scene-0015',
#  'scene-0016',
#  'scene-0017',
#  'scene-0018',
#  'scene-0035',
#  'scene-0036',
#  'scene-0038',
#  'scene-0039',
#  'scene-0092',
#  'scene-0093',
#  'scene-0094',
#  'scene-0095',
#  'scene-0096',
#  'scene-0097',
#  'scene-0098',
#  'scene-0099',
#  'scene-0100',
#  'scene-0101',
#  'scene-0102',
#  'scene-0103',
#  'scene-0104',
#  'scene-0105',
#  'scene-0106',
#  'scene-0107',
#  'scene-0108',
#  'scene-0109',
#  'scene-0110',
#  'scene-0221',
#  'scene-0268',
#  'scene-0269',
#  'scene-0270',
#  'scene-0271',
#  'scene-0272',
#  'scene-0273',
#  'scene-0274',
#  'scene-0275',
#  'scene-0276',
#  'scene-0277',
#  'scene-0278',
#  'scene-0329',
#  'scene-0330',
#  'scene-0331',
#  'scene-0332',
#  'scene-0344',
#  'scene-0345',
#  'scene-0346',
#  'scene-0519',
#  'scene-0520',
#  'scene-0521',
#  'scene-0522',
#  'scene-0523',
#  'scene-0524',
#  'scene-0552',
#  'scene-0553',
# ...
